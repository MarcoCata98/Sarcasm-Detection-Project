# %% [markdown]
# # Sarcasm-Detection-Project
# ## Definizione di IRONIA
# L’ironia è una figura retorica che esprime il contrario del significato letterale, suggerendo intenzionalmente un significato secondario o implicito.
# L'ambiguità dell ironia è completamente lessicale, questo la rende molto difficile da per sistemi informatici che operano solo sulla grammatica di un testo.
#
# Il termine Ironia e sinonimo di sarcasmo satira e parodia in base al contesto, che appunto determina quanto sia realistica la cosa appena detta.
# Alcuni testi, definiscono il sarcasmo come un ironia più fredda e tagliente allo scopo di deridere e offendere, per questo progetto tratteremo in modo uguale entrambi i termini.
#
# E quindi l'obbiettivo del progetto è definire un classificatore binario , dato in input un testo , ritorna un valore da 0 a 1 , 0 = classe negativa => non ironico,  1 = classe positiva => ironico
#
#
# ## Primo dataset: IronITA
# Il primo dataset utilizzato si chiama IronITA, proviene dal università di Torino, ed è stato creato per l'evento EVALITA 2018 (13 dicembre 2018), ideato per scoprire nuovi strumenti di Natural Processing e Speech.
# (Articolo estratto dal evento https://ceur-ws.org/Vol-2263/paper005.pdf, autori: Cignarella,Frenda,Basile,Bosco,Patti,Rosso).
#
# Il dataset contiene 3,977 tweets scelti con distribuzione uniforme dalla community di twitter italiana.
# per ogni frase registrata, vengono indicati 2 valori
